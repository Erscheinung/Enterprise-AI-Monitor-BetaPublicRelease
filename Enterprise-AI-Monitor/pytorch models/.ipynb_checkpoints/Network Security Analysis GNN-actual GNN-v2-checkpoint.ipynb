# %%
import sys
import torch
print("Python version:", sys.version)
print("Torch version:", torch.__version__)
print("CUDA available?", torch.cuda.is_available())
import pandas as pd
import numpy as np
from collections import defaultdict
from sklearn.utils.class_weight import compute_class_weight
import time
import random
import itertools
from sklearn.preprocessing import LabelEncoder, StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.neighbors import NearestNeighbors
from torch_geometric.data import Data
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
# Out:
# Python version: 3.9.21 | packaged by conda-forge | (main, Dec  5 2024, 13:41:22) [MSC v.1929 64 bit (AMD64)]
# Torch version: 2.5.1
# CUDA available? True

# %%
torch.cuda.empty_cache()

# %%
# Adjust filenames as needed
TRAIN_PATH = "UNSW_NB15_training-set.csv"
TEST_PATH  = "UNSW_NB15_testing-set.csv"

# 1) Read CSVs
train_df = pd.read_csv(TRAIN_PATH)
test_df = pd.read_csv(TEST_PATH)

# 2) Fill NaN in attack_cat
train_df = train_df.assign(attack_cat=train_df['attack_cat'].fillna('Normal'))
test_df = test_df.assign(attack_cat=test_df['attack_cat'].fillna('Normal'))

# 3) Encode 'attack_cat' as the label
attack_cat_encoder = LabelEncoder()
train_df['attack_cat'] = attack_cat_encoder.fit_transform(train_df['attack_cat'])
test_df['attack_cat'] = attack_cat_encoder.transform(test_df['attack_cat'])

# 4) Handle categorical columns more robustly
cat_cols = ['proto', 'service', 'state']
for col in cat_cols:
    # Get unique values from both train and test
    combined_categories = pd.concat([train_df[col], test_df[col]]).unique()
    le = LabelEncoder()
    le.fit(combined_categories.astype(str))
    
    # Transform separately
    train_df[col] = le.transform(train_df[col].astype(str))
    test_df[col] = le.transform(test_df[col].astype(str))

# Drop unused cols
drop_cols = ['id', 'label']
for c in drop_cols:
    if c in train_df.columns:
        train_df.drop(columns=c, inplace=True)
    if c in test_df.columns:
        test_df.drop(columns=c, inplace=True)

feature_cols = [c for c in train_df.columns if c != 'attack_cat']
X_train = train_df[feature_cols].values
y_train = train_df['attack_cat'].values
X_test = test_df[feature_cols].values
y_test = test_df['attack_cat'].values

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Train X shape:", X_train.shape, "y shape:", y_train.shape)
print("Test  X shape:", X_test.shape,  "y shape:", y_test.shape)
# Out:
# Train X shape: (175341, 42) y shape: (175341,)
# Test  X shape: (82332, 42) y shape: (82332,)

# %%
# # Instead of KNN, we'll connect flows (rows) if they share the same (proto, service, state).
# # WARNING: This can produce a very large adjacency if many rows share the same triple!

# # We'll do this for TRAIN. Each row is a node.
# # The columns for proto, service, state in the *scaled* matrix are no longer 
# # integers, so let's get them from the unscaled dataframe. That means we do:
# train_proto  = train_df['proto'].values
# train_service= train_df['service'].values
# train_state  = train_df['state'].values

# # Group rows by (proto, service, state)
# from collections import defaultdict
# groups = defaultdict(list)
# for i, (p, s, st) in enumerate(zip(train_proto, train_service, train_state)):
#     groups[(p,s,st)].append(i)

# edge_source = []
# edge_target = []
# # For each group, connect all nodes in that group fully
# # But if the group is huge, you might limit the number of edges
# for triple, indices in groups.items():
#     if len(indices) > 1:
#         # connect all pairs in 'indices'
#         # for large groups, you might want to do a random subset 
#         # or skip a big group to avoid excessive memory usage
#         for i in range(len(indices) - 1):
#             for j in range(i+1, len(indices)):
#                 node_i = indices[i]
#                 node_j = indices[j]
#                 edge_source.append(node_i)
#                 edge_target.append(node_j)
#                 edge_source.append(node_j)
#                 edge_target.append(node_i)

# edge_index_train = np.vstack((edge_source, edge_target))
# edge_index_train = torch.tensor(edge_index_train, dtype=torch.long)

# print("edge_index_train shape:", edge_index_train.shape)

# Code above did not work well, maybe LOTS OF ADJACENCY

# To reduce the combinatorial explosion we set thresholds.
VERBOSE = True
MAX_NODES_PER_GROUP = 500   # if a group has more than this, sample nodes
MAX_EDGES_PER_GROUP = 10000 # if full connectivity would produce too many edges, sample pairs

def create_edge_index(proto, service, state, max_nodes=MAX_NODES_PER_GROUP, 
                      max_edges=MAX_EDGES_PER_GROUP, verbose=False):
    groups = defaultdict(list)
    for i, (p, s, st) in enumerate(zip(proto, service, state)):
        groups[(p, s, st)].append(i)
    
    if verbose:
        num_groups = len(groups)
        max_group_size = max(len(idxs) for idxs in groups.values())
        print(f"Total groups: {num_groups}, Maximum group size: {max_group_size}")
    
    edge_source = []
    edge_target = []
    
    for triple, indices in groups.items():
        group_size = len(indices)
        if group_size <= 1:
            continue  # no edge possible
        
        # If the group is huge, sample a subset of nodes first
        if group_size > max_nodes:
            if verbose:
                print(f"Group {triple} has {group_size} nodes; sampling {max_nodes} nodes.")
            indices = random.sample(indices, max_nodes)
            group_size = max_nodes

        # Compute total possible undirected edges (each added in both directions)
        total_edges = group_size * (group_size - 1) // 2
        if total_edges > max_edges:
            # Instead of adding all pairs, sample a fixed number of edges
            if verbose:
                print(f"Group {triple} (size {group_size}) would produce {total_edges} edges; sampling {max_edges} pairs.")
            # Get all possible pairs, then sample (note: this list can be huge, so for extreme cases
            # consider an alternative random sampling without generating all pairs)
            all_pairs = list(itertools.combinations(indices, 2))
            sampled_pairs = random.sample(all_pairs, max_edges)
            for i, j in sampled_pairs:
                edge_source.extend([i, j])
                edge_target.extend([j, i])
        else:
            # Full connectivity for the group
            for i in range(group_size - 1):
                for j in range(i + 1, group_size):
                    edge_source.extend([indices[i], indices[j]])
                    edge_target.extend([indices[j], indices[i]])
    # Stack into array: shape (2, num_edges)
    return np.vstack((edge_source, edge_target))

# %%
# For training data

train_proto   = train_df['proto'].values
train_service = train_df['service'].values
train_state   = train_df['state'].values

edge_index_train_np = create_edge_index(train_proto, train_service, train_state, 
                                          max_nodes=MAX_NODES_PER_GROUP, 
                                          max_edges=MAX_EDGES_PER_GROUP, verbose=VERBOSE)
edge_index_train = torch.tensor(edge_index_train_np, dtype=torch.long)
print("edge_index_train shape:", edge_index_train.shape)
# Out:
# Total groups: 169, Maximum group size: 44185
# Group (113, 0, 4) has 44185 nodes; sampling 500 nodes.
# Group (113, 0, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 3, 4) has 3419 nodes; sampling 500 nodes.
# Group (113, 3, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 9, 4) has 5008 nodes; sampling 500 nodes.
# Group (113, 9, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 5, 4) has 18702 nodes; sampling 500 nodes.
# Group (113, 5, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 0, 5) has 12043 nodes; sampling 500 nodes.
# Group (119, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (6, 0, 5) has 2769 nodes; sampling 500 nodes.
# Group (6, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (78, 0, 5) has 1770 nodes; sampling 500 nodes.
# Group (78, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 4, 4) has 3993 nodes; sampling 500 nodes.
# Group (113, 4, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 2, 2) has 7592 nodes; sampling 500 nodes.
# Group (119, 2, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 0, 2) has 3723 nodes; sampling 500 nodes.
# Group (119, 0, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 11, 4) has 1292 nodes; sampling 500 nodes.
# Group (113, 11, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (78, 0, 7) has 825 nodes; sampling 500 nodes.
# Group (78, 0, 7) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 2, 5) has 39429 nodes; sampling 500 nodes.
# Group (119, 2, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 0, 2) has 1098 nodes; sampling 500 nodes.
# Group (113, 0, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 0, 7) has 856 nodes; sampling 500 nodes.
# Group (113, 0, 7) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (110, 0, 5) (size 201) would produce 20100 edges; sampling 10000 pairs.
# Group (120, 0, 5) has 12084 nodes; sampling 500 nodes.
# Group (120, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (111, 0, 5) (size 201) would produce 20100 edges; sampling 10000 pairs.
# Group (90, 0, 5) (size 200) would produce 19900 edges; sampling 10000 pairs.
# Group (100, 0, 5) (size 193) would produce 18528 edges; sampling 10000 pairs.
# Group (71, 0, 5) (size 201) would produce 20100 edges; sampling 10000 pairs.
# Group (97, 0, 5) has 620 nodes; sampling 500 nodes.
# Group (97, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (80, 0, 5) (size 201) would produce 20100 edges; sampling 10000 pairs.
# Group (3, 0, 5) (size 300) would produce 44850 edges; sampling 10000 pairs.
# Group (52, 0, 5) (size 201) would produce 20100 edges; sampling 10000 pairs.
# Group (32, 0, 5) (size 225) would produce 25200 edges; sampling 10000 pairs.
# Group (97, 0, 2) has 530 nodes; sampling 500 nodes.
# Group (97, 0, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 7, 4) has 1100 nodes; sampling 500 nodes.
# Group (113, 7, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 2, 7) (size 228) would produce 25878 edges; sampling 10000 pairs.
# edge_index_train shape: torch.Size([2, 1751590])

# %%
# Build the PyG Data for training
x_train_tensor = torch.tensor(X_train, dtype=torch.float)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

train_data = Data(
    x=x_train_tensor,
    y=y_train_tensor,
    edge_index=edge_index_train
)
print(train_data)
print("Train data: #nodes =", train_data.num_nodes, 
      "#edges =", train_data.num_edges, 
      "num_features =", train_data.num_features)
# Out:
# Data(x=[175341, 42], edge_index=[2, 1751590], y=[175341])
# Train data: #nodes = 175341 #edges = 1751590 num_features = 42

# %%
# --- For test data ---
test_proto   = test_df['proto'].values
test_service = test_df['service'].values
test_state   = test_df['state'].values

edge_index_test_np = create_edge_index(test_proto, test_service, test_state, 
                                         max_nodes=MAX_NODES_PER_GROUP, 
                                         max_edges=MAX_EDGES_PER_GROUP, verbose=VERBOSE)
edge_index_test = torch.tensor(edge_index_test_np, dtype=torch.long)
x_test_tensor = torch.tensor(X_test, dtype=torch.float)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
test_data = Data(
    x=x_test_tensor,
    y=y_test_tensor,
    edge_index=edge_index_test
)
print(test_data)
print("Test data: #nodes =", test_data.num_nodes, 
      "#edges =", test_data.num_edges, 
      "num_features =", test_data.num_features)
# Out:
# Total groups: 165, Maximum group size: 25629
# Group (119, 0, 5) has 6362 nodes; sampling 500 nodes.
# Group (119, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (6, 0, 5) has 926 nodes; sampling 500 nodes.
# Group (6, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 0, 4) has 25629 nodes; sampling 500 nodes.
# Group (113, 0, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 5, 4) has 8270 nodes; sampling 500 nodes.
# Group (113, 5, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 0, 7) has 1655 nodes; sampling 500 nodes.
# Group (113, 0, 7) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (78, 0, 5) has 524 nodes; sampling 500 nodes.
# Group (78, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (97, 0, 5) (size 205) would produce 20910 edges; sampling 10000 pairs.
# Group (113, 3, 4) has 1541 nodes; sampling 500 nodes.
# Group (113, 3, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 4, 4) has 1390 nodes; sampling 500 nodes.
# Group (113, 4, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 9, 4) has 1836 nodes; sampling 500 nodes.
# Group (113, 9, 4) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 7, 4) (size 420) would produce 87990 edges; sampling 10000 pairs.
# Group (119, 2, 5) has 18263 nodes; sampling 500 nodes.
# Group (119, 2, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 0, 2) has 1611 nodes; sampling 500 nodes.
# Group (119, 0, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (119, 2, 2) has 3083 nodes; sampling 500 nodes.
# Group (119, 2, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (120, 0, 5) has 3515 nodes; sampling 500 nodes.
# Group (120, 0, 5) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Group (113, 11, 4) (size 203) would produce 20503 edges; sampling 10000 pairs.
# Group (78, 0, 7) (size 152) would produce 11476 edges; sampling 10000 pairs.
# Group (113, 0, 2) has 2043 nodes; sampling 500 nodes.
# Group (113, 0, 2) (size 500) would produce 124750 edges; sampling 10000 pairs.
# Data(x=[82332, 42], edge_index=[2, 536916], y=[82332])
# Test data: #nodes = 82332 #edges = 536916 num_features = 42

# %%
# Experiment with different GCN
class GCN(torch.nn.Module):
    def __init__(self, num_features, hidden_channels, num_classes, dropout_p=0.5):
        super().__init__()
        self.conv1 = GCNConv(num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, num_classes)
        self.dropout_p = dropout_p
    
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout_p, training=self.training)
        x = self.conv2(x, edge_index)
        x = F.relu(x)
        x = F.dropout(x, p=self.dropout_p, training=self.training)
        x = self.conv3(x, edge_index)
        return x

# %%
# Training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Using device:", device)

num_features = train_data.num_features
num_classes = len(np.unique(y_train))
hidden_channels = 64

model = GCN(num_features, hidden_channels, num_classes, dropout_p=0.5).to(device)
train_data = train_data.to(device)
test_data = test_data.to(device)

# Compute class weights for balanced loss
from sklearn.utils.class_weight import compute_class_weight
classes = np.unique(y_train)
class_weights = compute_class_weight('balanced', classes=classes, y=y_train)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
# Out:
# Using device: cuda

# %%
# Training Loop

def train_one_epoch():
    model.train()
    optimizer.zero_grad()
    out = model(train_data.x, train_data.edge_index)
    loss = F.cross_entropy(out, train_data.y)
    loss.backward()
    optimizer.step()
    return loss.item()

epochs = 20
for epoch in range(1, epochs + 1):
    start_time = time.time()
    loss_val = train_one_epoch()
    elapsed = time.time() - start_time
    print(f"Epoch {epoch:02d}, Loss = {loss_val:.4f}, Time = {elapsed:.2f} sec")
# Out:
# Epoch 01, Loss = 0.6048, Time = 0.32 sec
# Epoch 02, Loss = 0.6042, Time = 0.06 sec
# Epoch 03, Loss = 0.6052, Time = 0.06 sec
# Epoch 04, Loss = 0.6044, Time = 0.06 sec
# Epoch 05, Loss = 0.6027, Time = 0.06 sec
# Epoch 06, Loss = 0.6032, Time = 0.05 sec
# Epoch 07, Loss = 0.6022, Time = 0.08 sec
# Epoch 08, Loss = 0.6026, Time = 0.06 sec
# Epoch 09, Loss = 0.6045, Time = 0.05 sec
# Epoch 10, Loss = 0.6024, Time = 0.05 sec
# Epoch 11, Loss = 0.6023, Time = 0.05 sec
# Epoch 12, Loss = 0.6026, Time = 0.06 sec
# Epoch 13, Loss = 0.6026, Time = 0.07 sec
# Epoch 14, Loss = 0.6008, Time = 0.05 sec
# Epoch 15, Loss = 0.6029, Time = 0.05 sec
# Epoch 16, Loss = 0.6032, Time = 0.06 sec
# Epoch 17, Loss = 0.6039, Time = 0.05 sec
# Epoch 18, Loss = 0.6018, Time = 0.06 sec
# Epoch 19, Loss = 0.6020, Time = 0.05 sec
# Epoch 20, Loss = 0.6028, Time = 0.05 sec

# %%
# Tracking training loss
loss_history = []
epochs = 500  # Increase epochs for better convergence
for epoch in range(1, epochs + 1):
    model.train()
    optimizer.zero_grad()
    out = model(train_data.x, train_data.edge_index)
    loss = F.cross_entropy(out, train_data.y, weight=class_weights)
    loss.backward()
    optimizer.step()
    loss_val = loss.item()
    loss_history.append(loss_val)
    print(f"Epoch {epoch:02d}, Loss = {loss_val:.4f}")

# Plot training loss after training
plt.figure(figsize=(8, 6))
plt.plot(range(1, epochs + 1), loss_history, marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss over Epochs')
plt.grid(True)
plt.show()
# Out:
# Epoch 01, Loss = 1.1204
# Epoch 02, Loss = 1.1228
# Epoch 03, Loss = 1.1285
# Epoch 04, Loss = 1.1279
# Epoch 05, Loss = 1.1217
# Epoch 06, Loss = 1.1219
# Epoch 07, Loss = 1.1268
# Epoch 08, Loss = 1.1149
# Epoch 09, Loss = 1.1257
# Epoch 10, Loss = 1.1144
# Epoch 11, Loss = 1.1155
# Epoch 12, Loss = 1.1286
# Epoch 13, Loss = 1.1138
# Epoch 14, Loss = 1.1139
# Epoch 15, Loss = 1.1127
# Epoch 16, Loss = 1.1135
# Epoch 17, Loss = 1.1101
# Epoch 18, Loss = 1.1173
# Epoch 19, Loss = 1.1056
# Epoch 20, Loss = 1.1129
# Epoch 21, Loss = 1.1098
# Epoch 22, Loss = 1.1110
# Epoch 23, Loss = 1.1185
# Epoch 24, Loss = 1.1144
# Epoch 25, Loss = 1.1186
# Epoch 26, Loss = 1.1150
# Epoch 27, Loss = 1.1156
# Epoch 28, Loss = 1.1156
# Epoch 29, Loss = 1.1067
# Epoch 30, Loss = 1.1124
# Epoch 31, Loss = 1.1103
# Epoch 32, Loss = 1.1142
# Epoch 33, Loss = 1.1009
# Epoch 34, Loss = 1.1026
# Epoch 35, Loss = 1.1042
# Epoch 36, Loss = 1.1098
# Epoch 37, Loss = 1.0977
# Epoch 38, Loss = 1.1100
# Epoch 39, Loss = 1.1064
# Epoch 40, Loss = 1.1044
# Epoch 41, Loss = 1.1113
# Epoch 42, Loss = 1.1051
# Epoch 43, Loss = 1.1066
# Epoch 44, Loss = 1.1012
# Epoch 45, Loss = 1.0995
# Epoch 46, Loss = 1.0984
# Epoch 47, Loss = 1.1092
# Epoch 48, Loss = 1.1093
# Epoch 49, Loss = 1.1049
# Epoch 50, Loss = 1.0971
# Epoch 51, Loss = 1.0975
# Epoch 52, Loss = 1.0965
# Epoch 53, Loss = 1.0966
# Epoch 54, Loss = 1.0953
# Epoch 55, Loss = 1.1004
# Epoch 56, Loss = 1.1019
# Epoch 57, Loss = 1.1024
# Epoch 58, Loss = 1.1103
# Epoch 59, Loss = 1.0972
# Epoch 60, Loss = 1.0889
# Epoch 61, Loss = 1.0936
# Epoch 62, Loss = 1.0946
# Epoch 63, Loss = 1.0935
# Epoch 64, Loss = 1.0871
# Epoch 65, Loss = 1.0930
# Epoch 66, Loss = 1.0960
# Epoch 67, Loss = 1.0943
# Epoch 68, Loss = 1.0867
# Epoch 69, Loss = 1.0906
# Epoch 70, Loss = 1.0837
# Epoch 71, Loss = 1.0814
# Epoch 72, Loss = 1.0967
# Epoch 73, Loss = 1.0927
# Epoch 74, Loss = 1.0831
# Epoch 75, Loss = 1.0928
# Epoch 76, Loss = 1.0886
# Epoch 77, Loss = 1.0872
# Epoch 78, Loss = 1.0861
# Epoch 79, Loss = 1.0856
# Epoch 80, Loss = 1.0847
# Epoch 81, Loss = 1.0867
# Epoch 82, Loss = 1.0860
# Epoch 83, Loss = 1.0822
# Epoch 84, Loss = 1.0849
# Epoch 85, Loss = 1.0756
# Epoch 86, Loss = 1.0936
# Epoch 87, Loss = 1.0859
# Epoch 88, Loss = 1.0912
# Epoch 89, Loss = 1.0871
# Epoch 90, Loss = 1.0824
# Epoch 91, Loss = 1.0787
# Epoch 92, Loss = 1.0858
# Epoch 93, Loss = 1.0789
# Epoch 94, Loss = 1.0792
# Epoch 95, Loss = 1.0824
# Epoch 96, Loss = 1.0843
# Epoch 97, Loss = 1.0767
# Epoch 98, Loss = 1.0811
# Epoch 99, Loss = 1.0858
# Epoch 100, Loss = 1.0813
# Epoch 101, Loss = 1.0890
# Epoch 102, Loss = 1.0806
# Epoch 103, Loss = 1.0791
# Epoch 104, Loss = 1.0814
# Epoch 105, Loss = 1.0794
# Epoch 106, Loss = 1.0831
# Epoch 107, Loss = 1.0716
# Epoch 108, Loss = 1.0829
# Epoch 109, Loss = 1.0831
# Epoch 110, Loss = 1.0789
# Epoch 111, Loss = 1.0732
# Epoch 112, Loss = 1.0742
# Epoch 113, Loss = 1.0828
# Epoch 114, Loss = 1.0717
# Epoch 115, Loss = 1.0771
# Epoch 116, Loss = 1.0729
# Epoch 117, Loss = 1.0791
# Epoch 118, Loss = 1.0720
# Epoch 119, Loss = 1.0753
# Epoch 120, Loss = 1.0703
# Epoch 121, Loss = 1.0779
# Epoch 122, Loss = 1.0779
# Epoch 123, Loss = 1.0710
# Epoch 124, Loss = 1.0660
# Epoch 125, Loss = 1.0839
# Epoch 126, Loss = 1.0768
# Epoch 127, Loss = 1.0712
# Epoch 128, Loss = 1.0800
# Epoch 129, Loss = 1.0692
# Epoch 130, Loss = 1.0709
# Epoch 131, Loss = 1.0829
# Epoch 132, Loss = 1.0671
# Epoch 133, Loss = 1.0735
# Epoch 134, Loss = 1.0711
# Epoch 135, Loss = 1.0730
# Epoch 136, Loss = 1.0813
# Epoch 137, Loss = 1.0712
# Epoch 138, Loss = 1.0691
# Epoch 139, Loss = 1.0655
# Epoch 140, Loss = 1.0703
# Epoch 141, Loss = 1.0751
# Epoch 142, Loss = 1.0669
# Epoch 143, Loss = 1.0578
# Epoch 144, Loss = 1.0660
# Epoch 145, Loss = 1.0652
# Epoch 146, Loss = 1.0666
# Epoch 147, Loss = 1.0699
# Epoch 148, Loss = 1.0662
# Epoch 149, Loss = 1.0595
# Epoch 150, Loss = 1.0710
# Epoch 151, Loss = 1.0654
# Epoch 152, Loss = 1.0585
# Epoch 153, Loss = 1.0660
# Epoch 154, Loss = 1.0631
# Epoch 155, Loss = 1.0658
# Epoch 156, Loss = 1.0648
# Epoch 157, Loss = 1.0570
# Epoch 158, Loss = 1.0600
# Epoch 159, Loss = 1.0694
# Epoch 160, Loss = 1.0586
# Epoch 161, Loss = 1.0585
# Epoch 162, Loss = 1.0634
# Epoch 163, Loss = 1.0523
# Epoch 164, Loss = 1.0556
# Epoch 165, Loss = 1.0574
# Epoch 166, Loss = 1.0640
# Epoch 167, Loss = 1.0616
# Epoch 168, Loss = 1.0589
# Epoch 169, Loss = 1.0616
# Epoch 170, Loss = 1.0563
# Epoch 171, Loss = 1.0621
# Epoch 172, Loss = 1.0524
# Epoch 173, Loss = 1.0578
# Epoch 174, Loss = 1.0608
# Epoch 175, Loss = 1.0580
# Epoch 176, Loss = 1.0606
# Epoch 177, Loss = 1.0490
# Epoch 178, Loss = 1.0601
# Epoch 179, Loss = 1.0579
# Epoch 180, Loss = 1.0523
# Epoch 181, Loss = 1.0554
# Epoch 182, Loss = 1.0678
# Epoch 183, Loss = 1.0626
# Epoch 184, Loss = 1.0584
# Epoch 185, Loss = 1.0577
# Epoch 186, Loss = 1.0554
# Epoch 187, Loss = 1.0580
# Epoch 188, Loss = 1.0567
# Epoch 189, Loss = 1.0564
# Epoch 190, Loss = 1.0656
# Epoch 191, Loss = 1.0530
# Epoch 192, Loss = 1.0652
# Epoch 193, Loss = 1.0582
# Epoch 194, Loss = 1.0644
# Epoch 195, Loss = 1.0465
# Epoch 196, Loss = 1.0611
# Epoch 197, Loss = 1.0599
# Epoch 198, Loss = 1.0612
# Epoch 199, Loss = 1.0518
# Epoch 200, Loss = 1.0517
# Epoch 201, Loss = 1.0614
# Epoch 202, Loss = 1.0541
# Epoch 203, Loss = 1.0576
# Epoch 204, Loss = 1.0493
# Epoch 205, Loss = 1.0588
# Epoch 206, Loss = 1.0579
# Epoch 207, Loss = 1.0543
# Epoch 208, Loss = 1.0577
# Epoch 209, Loss = 1.0580
# Epoch 210, Loss = 1.0479
# Epoch 211, Loss = 1.0446
# Epoch 212, Loss = 1.0534
# Epoch 213, Loss = 1.0436
# Epoch 214, Loss = 1.0503
# Epoch 215, Loss = 1.0473
# Epoch 216, Loss = 1.0608
# Epoch 217, Loss = 1.0542
# Epoch 218, Loss = 1.0551
# Epoch 219, Loss = 1.0488
# Epoch 220, Loss = 1.0513
# Epoch 221, Loss = 1.0481
# Epoch 222, Loss = 1.0484
# Epoch 223, Loss = 1.0447
# Epoch 224, Loss = 1.0477
# Epoch 225, Loss = 1.0495
# Epoch 226, Loss = 1.0426
# Epoch 227, Loss = 1.0445
# Epoch 228, Loss = 1.0441
# Epoch 229, Loss = 1.0385
# Epoch 230, Loss = 1.0566
# Epoch 231, Loss = 1.0491
# Epoch 232, Loss = 1.0478
# Epoch 233, Loss = 1.0402
# Epoch 234, Loss = 1.0385
# Epoch 235, Loss = 1.0440
# Epoch 236, Loss = 1.0506
# Epoch 237, Loss = 1.0414
# Epoch 238, Loss = 1.0561
# Epoch 239, Loss = 1.0466
# Epoch 240, Loss = 1.0447
# Epoch 241, Loss = 1.0479
# Epoch 242, Loss = 1.0387
# Epoch 243, Loss = 1.0504
# Epoch 244, Loss = 1.0423
# Epoch 245, Loss = 1.0412
# Epoch 246, Loss = 1.0412
# Epoch 247, Loss = 1.0407
# Epoch 248, Loss = 1.0462
# Epoch 249, Loss = 1.0462
# Epoch 250, Loss = 1.0428
# Epoch 251, Loss = 1.0385
# Epoch 252, Loss = 1.0506
# Epoch 253, Loss = 1.0578
# Epoch 254, Loss = 1.0511
# Epoch 255, Loss = 1.0467
# Epoch 256, Loss = 1.0433
# Epoch 257, Loss = 1.0518
# Epoch 258, Loss = 1.0384
# Epoch 259, Loss = 1.0414
# Epoch 260, Loss = 1.0432
# Epoch 261, Loss = 1.0420
# Epoch 262, Loss = 1.0388
# Epoch 263, Loss = 1.0353
# Epoch 264, Loss = 1.0444
# Epoch 265, Loss = 1.0442
# Epoch 266, Loss = 1.0432
# Epoch 267, Loss = 1.0444
# Epoch 268, Loss = 1.0468
# Epoch 269, Loss = 1.0385
# Epoch 270, Loss = 1.0483
# Epoch 271, Loss = 1.0491
# Epoch 272, Loss = 1.0414
# Epoch 273, Loss = 1.0430
# Epoch 274, Loss = 1.0478
# Epoch 275, Loss = 1.0523
# Epoch 276, Loss = 1.0459
# Epoch 277, Loss = 1.0442
# Epoch 278, Loss = 1.0402
# Epoch 279, Loss = 1.0423
# Epoch 280, Loss = 1.0413
# Epoch 281, Loss = 1.0446
# Epoch 282, Loss = 1.0396
# Epoch 283, Loss = 1.0479
# Epoch 284, Loss = 1.0411
# Epoch 285, Loss = 1.0401
# Epoch 286, Loss = 1.0423
# Epoch 287, Loss = 1.0340
# Epoch 288, Loss = 1.0378
# Epoch 289, Loss = 1.0293
# Epoch 290, Loss = 1.0337
# Epoch 291, Loss = 1.0379
# Epoch 292, Loss = 1.0391
# Epoch 293, Loss = 1.0382
# Epoch 294, Loss = 1.0383
# Epoch 295, Loss = 1.0405
# Epoch 296, Loss = 1.0404
# Epoch 297, Loss = 1.0405
# Epoch 298, Loss = 1.0392
# Epoch 299, Loss = 1.0400
# Epoch 300, Loss = 1.0483
# Epoch 301, Loss = 1.0357
# Epoch 302, Loss = 1.0264
# Epoch 303, Loss = 1.0310
# Epoch 304, Loss = 1.0396
# Epoch 305, Loss = 1.0410
# Epoch 306, Loss = 1.0346
# Epoch 307, Loss = 1.0442
# Epoch 308, Loss = 1.0346
# Epoch 309, Loss = 1.0378
# Epoch 310, Loss = 1.0377
# Epoch 311, Loss = 1.0353
# Epoch 312, Loss = 1.0433
# Epoch 313, Loss = 1.0347
# Epoch 314, Loss = 1.0374
# Epoch 315, Loss = 1.0348
# Epoch 316, Loss = 1.0335
# Epoch 317, Loss = 1.0294
# Epoch 318, Loss = 1.0329
# Epoch 319, Loss = 1.0346
# Epoch 320, Loss = 1.0309
# Epoch 321, Loss = 1.0339
# Epoch 322, Loss = 1.0276
# Epoch 323, Loss = 1.0390
# Epoch 324, Loss = 1.0324
# Epoch 325, Loss = 1.0359
# Epoch 326, Loss = 1.0309
# Epoch 327, Loss = 1.0318
# Epoch 328, Loss = 1.0319
# Epoch 329, Loss = 1.0332
# Epoch 330, Loss = 1.0323
# Epoch 331, Loss = 1.0368
# Epoch 332, Loss = 1.0371
# Epoch 333, Loss = 1.0326
# Epoch 334, Loss = 1.0322
# Epoch 335, Loss = 1.0348
# Epoch 336, Loss = 1.0361
# Epoch 337, Loss = 1.0312
# Epoch 338, Loss = 1.0324
# Epoch 339, Loss = 1.0294
# Epoch 340, Loss = 1.0283
# Epoch 341, Loss = 1.0326
# Epoch 342, Loss = 1.0333
# Epoch 343, Loss = 1.0320
# Epoch 344, Loss = 1.0275
# Epoch 345, Loss = 1.0369
# Epoch 346, Loss = 1.0276
# Epoch 347, Loss = 1.0304
# Epoch 348, Loss = 1.0208
# Epoch 349, Loss = 1.0360
# Epoch 350, Loss = 1.0262
# Epoch 351, Loss = 1.0341
# Epoch 352, Loss = 1.0337
# Epoch 353, Loss = 1.0297
# Epoch 354, Loss = 1.0313
# Epoch 355, Loss = 1.0291
# Epoch 356, Loss = 1.0229
# Epoch 357, Loss = 1.0308
# Epoch 358, Loss = 1.0414
# Epoch 359, Loss = 1.0338
# Epoch 360, Loss = 1.0326
# Epoch 361, Loss = 1.0229
# Epoch 362, Loss = 1.0194
# Epoch 363, Loss = 1.0478
# Epoch 364, Loss = 1.0347
# Epoch 365, Loss = 1.0399
# Epoch 366, Loss = 1.0274
# Epoch 367, Loss = 1.0301
# Epoch 368, Loss = 1.0365
# Epoch 369, Loss = 1.0311
# Epoch 370, Loss = 1.0301
# Epoch 371, Loss = 1.0215
# Epoch 372, Loss = 1.0314
# Epoch 373, Loss = 1.0287
# Epoch 374, Loss = 1.0313
# Epoch 375, Loss = 1.0228
# Epoch 376, Loss = 1.0302
# Epoch 377, Loss = 1.0259
# Epoch 378, Loss = 1.0249
# Epoch 379, Loss = 1.0269
# Epoch 380, Loss = 1.0262
# Epoch 381, Loss = 1.0309
# Epoch 382, Loss = 1.0231
# Epoch 383, Loss = 1.0316
# Epoch 384, Loss = 1.0344
# Epoch 385, Loss = 1.0296
# Epoch 386, Loss = 1.0236
# Epoch 387, Loss = 1.0341
# Epoch 388, Loss = 1.0234
# Epoch 389, Loss = 1.0238
# Epoch 390, Loss = 1.0293
# Epoch 391, Loss = 1.0251
# Epoch 392, Loss = 1.0228
# Epoch 393, Loss = 1.0308
# Epoch 394, Loss = 1.0217
# Epoch 395, Loss = 1.0235
# Epoch 396, Loss = 1.0180
# Epoch 397, Loss = 1.0251
# Epoch 398, Loss = 1.0211
# Epoch 399, Loss = 1.0277
# Epoch 400, Loss = 1.0261
# Epoch 401, Loss = 1.0221
# Epoch 402, Loss = 1.0242
# Epoch 403, Loss = 1.0295
# Epoch 404, Loss = 1.0203
# Epoch 405, Loss = 1.0293
# Epoch 406, Loss = 1.0241
# Epoch 407, Loss = 1.0201
# Epoch 408, Loss = 1.0214
# Epoch 409, Loss = 1.0200
# Epoch 410, Loss = 1.0235
# Epoch 411, Loss = 1.0132
# Epoch 412, Loss = 1.0159
# Epoch 413, Loss = 1.0219
# Epoch 414, Loss = 1.0220
# Epoch 415, Loss = 1.0130
# Epoch 416, Loss = 1.0223
# Epoch 417, Loss = 1.0142
# Epoch 418, Loss = 1.0150
# Epoch 419, Loss = 1.0274
# Epoch 420, Loss = 1.0251
# Epoch 421, Loss = 1.0176
# Epoch 422, Loss = 1.0180
# Epoch 423, Loss = 1.0347
# Epoch 424, Loss = 1.0273
# Epoch 425, Loss = 1.0156
# Epoch 426, Loss = 1.0244
# Epoch 427, Loss = 1.0281
# Epoch 428, Loss = 1.0313
# Epoch 429, Loss = 1.0176
# Epoch 430, Loss = 1.0249
# Epoch 431, Loss = 1.0254
# Epoch 432, Loss = 1.0246
# Epoch 433, Loss = 1.0290
# Epoch 434, Loss = 1.0336
# Epoch 435, Loss = 1.0219
# Epoch 436, Loss = 1.0216
# Epoch 437, Loss = 1.0142
# Epoch 438, Loss = 1.0249
# Epoch 439, Loss = 1.0245
# Epoch 440, Loss = 1.0227
# Epoch 441, Loss = 1.0231
# Epoch 442, Loss = 1.0212
# Epoch 443, Loss = 1.0263
# Epoch 444, Loss = 1.0215
# Epoch 445, Loss = 1.0164
# Epoch 446, Loss = 1.0198
# Epoch 447, Loss = 1.0220
# Epoch 448, Loss = 1.0193
# Epoch 449, Loss = 1.0287
# Epoch 450, Loss = 1.0259
# Epoch 451, Loss = 1.0205
# Epoch 452, Loss = 1.0235
# Epoch 453, Loss = 1.0185
# Epoch 454, Loss = 1.0202
# Epoch 455, Loss = 1.0189
# Epoch 456, Loss = 1.0185
# Epoch 457, Loss = 1.0200
# Epoch 458, Loss = 1.0200
# Epoch 459, Loss = 1.0126
# Epoch 460, Loss = 1.0224
# Epoch 461, Loss = 1.0162
# Epoch 462, Loss = 1.0160
# Epoch 463, Loss = 1.0240
# Epoch 464, Loss = 1.0306
# Epoch 465, Loss = 1.0168
# Epoch 466, Loss = 1.0172
# Epoch 467, Loss = 1.0138
# Epoch 468, Loss = 1.0236
# Epoch 469, Loss = 1.0185
# Epoch 470, Loss = 1.0213
# Epoch 471, Loss = 1.0231
# Epoch 472, Loss = 1.0133
# Epoch 473, Loss = 1.0164
# Epoch 474, Loss = 1.0061
# Epoch 475, Loss = 1.0197
# Epoch 476, Loss = 1.0192
# Epoch 477, Loss = 1.0194
# Epoch 478, Loss = 1.0177
# Epoch 479, Loss = 1.0202
# Epoch 480, Loss = 1.0239
# Epoch 481, Loss = 1.0181
# Epoch 482, Loss = 1.0159
# Epoch 483, Loss = 1.0191
# Epoch 484, Loss = 1.0131
# Epoch 485, Loss = 1.0314
# Epoch 486, Loss = 1.0233
# Epoch 487, Loss = 1.0203
# Epoch 488, Loss = 1.0161
# Epoch 489, Loss = 1.0234
# Epoch 490, Loss = 1.0204
# Epoch 491, Loss = 1.0224
# Epoch 492, Loss = 1.0040
# Epoch 493, Loss = 1.0169
# Epoch 494, Loss = 1.0224
# Epoch 495, Loss = 1.0216
# Epoch 496, Loss = 1.0251
# Epoch 497, Loss = 1.0142
# Epoch 498, Loss = 1.0198
# Epoch 499, Loss = 1.0161
# Epoch 500, Loss = 1.0136

# %%
# Results
def evaluate(data):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1).cpu().numpy()
        labels = data.y.cpu().numpy()
    return pred, labels

# Evaluate on TRAIN data
train_pred, train_labels = evaluate(train_data)
cm_train = confusion_matrix(train_labels, train_pred)
print("\n=== Confusion Matrix (Train) ===")
print(cm_train)
print("\n=== Classification Report (Train) ===")
print(classification_report(train_labels, train_pred, target_names=attack_cat_encoder.classes_))

# Evaluate on TEST data
test_pred, test_labels = evaluate(test_data)
cm_test = confusion_matrix(test_labels, test_pred)
print("\n=== Confusion Matrix (Test) ===")
print(cm_test)
print("\n=== Classification Report (Test) ===")
print(classification_report(test_labels, test_pred, target_names=attack_cat_encoder.classes_))
# Out:
# === Confusion Matrix (Train) ===
# [[   83     0     0  1578     1     0   318    20     0     0]
#  [    0     0     0  1564    42     0     5   135     0     0]
#  [    0     0     6 11532   298    37    60   310    21     0]
#  [    0     0     0 30460  1364    12   416  1127    14     0]
#  [    0     0     0  2092 14968    16   481   616    11     0]
#  [    0     0     0   718   126 39115    11    26     4     0]
#  [   11     0     0  1150  9183     1 45398   257     0     0]
#  [    0     0     0  2512   456    72    55  7396     0     0]
#  [    0     0     0   168   261     0     9   630    65     0]
#  [    0     0     0   115    14     0     1     0     0     0]]
#
# === Classification Report (Train) ===
#                 precision    recall  f1-score   support
#
#       Analysis       0.88      0.04      0.08      2000
#       Backdoor       0.00      0.00      0.00      1746
#            DoS       1.00      0.00      0.00     12264
#       Exploits       0.59      0.91      0.71     33393
#        Fuzzers       0.56      0.82      0.67     18184
#        Generic       1.00      0.98      0.99     40000
#         Normal       0.97      0.81      0.88     56000
# Reconnaissance       0.70      0.70      0.70     10491
#      Shellcode       0.57      0.06      0.10      1133
#          Worms       0.00      0.00      0.00       130
#
#       accuracy                           0.78    175341
#      macro avg       0.63      0.43      0.41    175341
#   weighted avg       0.83      0.78      0.76    175341
#
#
# === Confusion Matrix (Test) ===
# [[    0     0    15   571    16    15     6    54     0     0]
#  [    0     0    15   449    25    17     3    74     0     0]
#  [    0     0    52  3639   181    29    33   144    11     0]
#  [   16     0    55  9804   587    41   231   392     6     0]
#  [    0     0    25  1267  4137    31   259   338     5     0]
#  [    0     0     1   494   294 17952    93    34     3     0]
#  [   52     0     0  1812 11714    17 22679   715    11     0]
#  [    0     0     5   648   227     5    16  2595     0     0]
#  [    0     0     0    61    82     0     4   207    24     0]
#  [    0     0     0    35     9     0     0     0     0     0]]
#
# === Classification Report (Test) ===
#                 precision    recall  f1-score   support
#
#       Analysis       0.00      0.00      0.00       677
#       Backdoor       0.00      0.00      0.00       583
#            DoS       0.31      0.01      0.02      4089
#       Exploits       0.52      0.88      0.66     11132
#        Fuzzers       0.24      0.68      0.35      6062
#        Generic       0.99      0.95      0.97     18871
#         Normal       0.97      0.61      0.75     37000
# Reconnaissance       0.57      0.74      0.64      3496
#      Shellcode       0.40      0.06      0.11       378
#          Worms       0.00      0.00      0.00        44
#
#       accuracy                           0.70     82332
#      macro avg       0.40      0.39      0.35     82332
#   weighted avg       0.79      0.70      0.70     82332
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# --- Function to Plot Confusion Matrix ---
def plot_confusion_matrix(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues):
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap=cmap,
                xticklabels=classes, yticklabels=classes)
    plt.title(title)
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# --- Function to Plot Classification Report as a Heatmap ---
def plot_classification_report(cr_dict, title='Classification Report', cmap='YlGnBu'):
    # Convert the classification report dictionary to a DataFrame.
    # Note: This will include overall metrics like accuracy, macro avg, weighted avg.
    # If you wish to plot only per-class metrics, you can filter out those rows.
    cr_df = pd.DataFrame(cr_dict).transpose()
    # Optionally drop rows that are not classes (adjust if needed)
    cr_df = cr_df.drop(['accuracy', 'macro avg', 'weighted avg'], errors='ignore')
    
    # Remove the support column if you don't want to plot it
    if 'support' in cr_df.columns:
        cr_df = cr_df.drop(['support'], axis=1)
    
    plt.figure(figsize=(10, 8))
    sns.heatmap(cr_df, annot=True, cmap=cmap, fmt=".2f")
    plt.title(title)
    plt.ylabel('Classes')
    plt.xlabel('Metrics')
    plt.show()

# --- Evaluate your model and generate reports as before ---
def evaluate(data):
    model.eval()
    with torch.no_grad():
        out = model(data.x, data.edge_index)
        pred = out.argmax(dim=1).cpu().numpy()
        labels = data.y.cpu().numpy()
    return pred, labels

# Evaluate on TRAIN data
train_pred, train_labels = evaluate(train_data)
cm_train = confusion_matrix(train_labels, train_pred)
print("\n=== Confusion Matrix (Train) ===")
print(cm_train)
print("\n=== Classification Report (Train) ===")
print(classification_report(train_labels, train_pred, target_names=attack_cat_encoder.classes_))

# Evaluate on TEST data
test_pred, test_labels = evaluate(test_data)
cm_test = confusion_matrix(test_labels, test_pred)
print("\n=== Confusion Matrix (Test) ===")
print(cm_test)
print("\n=== Classification Report (Test) ===")
print(classification_report(test_labels, test_pred, target_names=attack_cat_encoder.classes_))

# --- Plot the Graphical Outputs ---
# Plot Confusion Matrices
plot_confusion_matrix(cm_train, classes=attack_cat_encoder.classes_, title='Train Confusion Matrix')
plot_confusion_matrix(cm_test, classes=attack_cat_encoder.classes_, title='Test Confusion Matrix')

# Get classification reports as dictionaries for plotting
cr_train = classification_report(train_labels, train_pred, target_names=attack_cat_encoder.classes_, output_dict=True)
cr_test = classification_report(test_labels, test_pred, target_names=attack_cat_encoder.classes_, output_dict=True)

# Plot Classification Reports
plot_classification_report(cr_train, title='Train Classification Report')
plot_classification_report(cr_test, title='Test Classification Report')
# Out:
# === Confusion Matrix (Train) ===
# [[   83     0     0  1578     1     0   318    20     0     0]
#  [    0     0     0  1564    42     0     5   135     0     0]
#  [    0     0     6 11532   298    37    60   310    21     0]
#  [    0     0     0 30460  1364    12   416  1127    14     0]
#  [    0     0     0  2092 14968    16   481   616    11     0]
#  [    0     0     0   718   126 39115    11    26     4     0]
#  [   11     0     0  1150  9183     1 45398   257     0     0]
#  [    0     0     0  2512   456    72    55  7396     0     0]
#  [    0     0     0   168   261     0     9   630    65     0]
#  [    0     0     0   115    14     0     1     0     0     0]]
#
# === Classification Report (Train) ===
#                 precision    recall  f1-score   support
#
#       Analysis       0.88      0.04      0.08      2000
#       Backdoor       0.00      0.00      0.00      1746
#            DoS       1.00      0.00      0.00     12264
#       Exploits       0.59      0.91      0.71     33393
#        Fuzzers       0.56      0.82      0.67     18184
#        Generic       1.00      0.98      0.99     40000
#         Normal       0.97      0.81      0.88     56000
# Reconnaissance       0.70      0.70      0.70     10491
#      Shellcode       0.57      0.06      0.10      1133
#          Worms       0.00      0.00      0.00       130
#
#       accuracy                           0.78    175341
#      macro avg       0.63      0.43      0.41    175341
#   weighted avg       0.83      0.78      0.76    175341
#
#
# === Confusion Matrix (Test) ===
# [[    0     0    15   571    16    15     6    54     0     0]
#  [    0     0    15   449    25    17     3    74     0     0]
#  [    0     0    52  3639   181    29    33   144    11     0]
#  [   16     0    55  9804   587    41   231   392     6     0]
#  [    0     0    25  1267  4137    31   259   338     5     0]
#  [    0     0     1   494   294 17952    93    34     3     0]
#  [   52     0     0  1812 11714    17 22679   715    11     0]
#  [    0     0     5   648   227     5    16  2595     0     0]
#  [    0     0     0    61    82     0     4   207    24     0]
#  [    0     0     0    35     9     0     0     0     0     0]]
#
# === Classification Report (Test) ===
#                 precision    recall  f1-score   support
#
#       Analysis       0.00      0.00      0.00       677
#       Backdoor       0.00      0.00      0.00       583
#            DoS       0.31      0.01      0.02      4089
#       Exploits       0.52      0.88      0.66     11132
#        Fuzzers       0.24      0.68      0.35      6062
#        Generic       0.99      0.95      0.97     18871
#         Normal       0.97      0.61      0.75     37000
# Reconnaissance       0.57      0.74      0.64      3496
#      Shellcode       0.40      0.06      0.11       378
#          Worms       0.00      0.00      0.00        44
#
#       accuracy                           0.70     82332
#      macro avg       0.40      0.39      0.35     82332
#   weighted avg       0.79      0.70      0.70     82332
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\91965\anaconda3\envs\infra-env\lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Save Model
torch.save(model, "gnn_model_actual_v2.pt")

# Save weights
torch.save(model.state_dict(), "gnn_model_actual_v2_weights.pt")

print("\nModel and weights saved locally!")
# Out:
# Model and weights saved locally!
